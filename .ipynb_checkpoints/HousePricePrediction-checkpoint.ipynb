# %% [markdown]
# # Problem Definition

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Data Exploration

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Dropping any useless columns

# %%
df.isnull().sum().sort_values(ascending = False).head(20)   #checking for the amount of null values
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# Condition2         0
# dtype: int64

# %% [markdown]
# Seems like poolQC, miscfeature, alley and fence have the highest number of null values
# lets drop em

# %%
df.drop(["PoolQC", "MiscFeature", "Alley", "Fence"], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (1460, 77)

# %%
df.isnull().sum().sort_values(ascending=False).head(16)
# Out:
# MasVnrType      872
# FireplaceQu     690
# LotFrontage     259
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# GarageType       81
# GarageYrBlt      81
# BsmtExposure     38
# BsmtFinType2     38
# BsmtCond         37
# BsmtFinType1     37
# BsmtQual         37
# MasVnrArea        8
# Electrical        1
# LandSlope         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
#lets drip ID since we already have sr no.s 
df.drop(columns = ["Id"], inplace = True)

# %%
df.shape
# Out:
# (1460, 76)

# %%
# A bit of visualization
df.select_dtypes(include=['int64', 'float64']).sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # A bit of visualization
# ----> 2 df.select_dtypes(include=['int64', 'float64']).sort_values(ascending = False)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %% [markdown]
# # Missing Values
# Since there are many NAN values, we must change the categorical values to None and their sub columns to 0.
# This is because if lets say a house doesnt have a basement that means their basement's measurements (e.g. area) are 0

# %%
df[['MasVnrType', 'FireplaceQu', 'LotFrontage', 'GarageFinish', 'GarageQual','GarageCond', 'GarageType', 'GarageYrBlt', 'BsmtExposure', 'BsmtFinType2','BsmtCond', 'BsmtFinType1', 'BsmtQual', 'MasVnrArea', 'Electrical']].dtypes
# Out:
# MasVnrType       object
# FireplaceQu      object
# LotFrontage     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# GarageType       object
# GarageYrBlt     float64
# BsmtExposure     object
# BsmtFinType2     object
# BsmtCond         object
# BsmtFinType1     object
# BsmtQual         object
# MasVnrArea      float64
# Electrical       object
# dtype: object

# %%
# since 3 of them are float types, we'll fill 2 with 0s and only the LotFrontage with its median
#This is because there just cant be 0 front area infront of the house
#we'll fill the obj types with None since they're categorical values (non numeric)

non_numeric_cols = ['MasVnrType', 'FireplaceQu','GarageFinish', 'GarageQual','GarageCond', 'GarageType', 'BsmtExposure', 'BsmtFinType2','BsmtCond', 'BsmtFinType1', 'BsmtQual']
numeric_cols = ['GarageYrBlt', 'MasVnrArea']
#frontage_col = ['LotFrontage']
for c in non_numeric_cols:
    df[c] = df[c].fillna('None')

for c in numeric_cols:
    df[c] = df[c].fillna(0)

#gonna group it by neigborhood
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform('median')
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].median())   #in case there are NaNs

# %%
df['Electrical'].value_counts(dropna=False)
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: count, dtype: int64

# %%
# since electrical only has 1 NaN val, we should prolly fill it with the mode instead of None
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %%
df.isnull().sum().sort_values(ascending=False).head(16)
# Out:
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# dtype: int64

# %% [markdown]
# ### Removed all missing values!
